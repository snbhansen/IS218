# %% [markdown]
# #Romslig analyse av beredskapsressurser i Norge.
# Dette er en analyse av tilfluktsrom, brannstasjoner, drikkevann og sykehus. Målet er å undersøke dekning og nærhet mellom ressurser.

# %%
import pandas as pd
import geopandas as gpd
import shapely.geometry as Point
import matplotlib.pyplot as plt
import folium

# %%
# !pip install geopandas
# Out:
# ...
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ----- ---------------------------------- 3.1/22.9 MB 21.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 10.0/22.9 MB 20.0 MB/s eta 0:00:01
#    ------------------------- -------------- 14.7/22.9 MB 22.7 MB/s eta 0:00:01
#    ------------------------------ --------- 17.3/22.9 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 20.4 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 17.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------  6.3/6.3 MB 32.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 26.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 25.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [shapely]
# ...

# %%
# !pip install folium
# Out:
# ...
#
#    ---------------------------------------- 0/2 [branca]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    ---------------------------------------- 2/2 [folium]
#
# ...
